# %%
pip install kafka-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from kafka import KafkaProducer
from time import sleep
from json import dumps
import json

# %%
producer = KafkaProducer(bootstrap_servers=['13.60.227.126:9092'], 
                         value_serializer=lambda x: 
                         dumps(x).encode('utf-8'))

# %%
producer.send('network_testing2', value={'message':'hello kafka'})

# %%
df = pd.read_csv(r"C:\Users\shaik\Downloads\institutions\institutions\agg_1_day\1.csv")

# %%
df.head()
# Out:
#    id_time   n_flows   n_packets        n_bytes  sum_n_dest_asn  \
# 0        0  29554212  1623785921  1612575408926         7008679
# 1        1  37354624  1500996054  1471373785922         6942562
# 2        2  26158155  1591651251  1592071433811         6686352
# 3        3  26349247  1430752119  1406327722580         6422397
# 4        4  22925708  1322644646  1303490076977         5888247
#
#    average_n_dest_asn  std_n_dest_asn  sum_n_dest_ports  average_n_dest_ports  \
# 0                5.60           25.18          11980431                  9.58
# 1                5.36           21.60          13849112                 10.69
# 2                5.47           23.79          15853265                 12.98
# 3                5.54           23.66          15997441                 13.81
# 4                6.43           27.95          13806547                 15.08
#
#    std_n_dest_ports  sum_n_dest_ip  average_n_dest_ip  std_n_dest_ip  \
# ...

# %%
import time
for _, row in df.iterrows():
    message = row.to_dict()
    producer.send("network_testing2", value=message)
    print(f"Sent: {message}")
    time.sleep(0.5)
# Out:
# Sent: {'id_time': 0.0, 'n_flows': 29554212.0, 'n_packets': 1623785921.0, 'n_bytes': 1612575408926.0, 'sum_n_dest_asn': 7008679.0, 'average_n_dest_asn': 5.6, 'std_n_dest_asn': 25.18, 'sum_n_dest_ports': 11980431.0, 'average_n_dest_ports': 9.58, 'std_n_dest_ports': 230.28, 'sum_n_dest_ip': 15130839.0, 'average_n_dest_ip': 12.09, 'std_n_dest_ip': 239.56, 'tcp_udp_ratio_packets': 0.8, 'tcp_udp_ratio_bytes': 0.81, 'dir_ratio_packets': 0.45, 'dir_ratio_bytes': 0.43, 'avg_duration': 19.17, 'avg_ttl': 149.31}
# ...
